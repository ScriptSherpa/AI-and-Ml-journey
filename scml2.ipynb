# %% [markdown]
# <a href="https://colab.research.google.com/github/ScriptSherpa/AI-and-Ml-journey/blob/main/scml2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x =np.array([1, 2, 3, 4, 5, 6])
y= np.array([7, 8, 9, 10, 11, 12])
z=np.array([13, 14, 15, 16, 17, 18])
w=np.array([19, 20, 21, 22, 23, 24])

# %%
plt.plot (x,y);

# %%
plt.title(' change in y w.r.t.x')
plt.xlabel('x values')
plt.ylabel('y values')
plt.plot(x, y, marker = 'o', mfc='red') # Changed marker style to 'o'
plt.grid()

# %%
courses = ['python','java','dart', 'c++', 'kotrin']
student = [56,61,46,70,30]

# %%
plt.bar(courses, student, color = 'red');

# %%
plt.title('student enrollment in courses')
plt.xlabel('courses')
plt.ylabel('number of students')
plt.bar(courses, student, color = 'blue', alpha =0.6);
plt.grid();

# %%
df=pd.read_csv('/content/student-dataset.csv')
df
# Out:
#       id               name               nationality                 city  \
# 0      0          Kiana Lor                     China               Suzhou
# 1      1     Joshua Lonaker  United States of America        Santa Clarita
# 2      2      Dakota Blanco  United States of America              Oakland
# 3      3    Natasha Yarusso  United States of America        Castro Valley
# 4      4     Brooke Cazares                    Brazil  São José dos Campos
# ..   ...                ...                       ...                  ...
# 302  302        Austin Haas  United States of America             Columbus
# 303  303    Madison Fithian  United States of America          Los Angeles
# 304  304  Zachary Mulvahill  United States of America          Los Angeles
# 305  305   Eliana Michelsen  United States of America              Oakland
# 306  306    Dane Whittemore                    Canada              Toronto
#
# ...

# %%
plt.bar(df['name'], df['english.grade'], color = 'blue');

# %%
plt.figure(figsize=(16, 9)) # Changed figsize to a tuple of width and height.
plt.title('customers')
plt.xlabel('math.grade') # Corrected the typo from 'xlable' to 'xlabel'.
plt.ylabel('english.grade')
plt.bar(df['name'], df['english.grade'], color = 'blue');
plt.grid()

# %%
purchase_counts = dd['Purchased'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(purchase_counts, labels=purchase_counts.index, autopct='%.2f%%', startangle=90)
plt.title('Purchase Distribution')
plt.show()

# %%
purchase_counts = dd['Purchased'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(purchase_counts, labels=purchase_counts.index, autopct='%.2f%%', startangle=90)
plt.title('Purchase Distribution')
plt.show()

# %%
purchase_counts = dd['Purchased'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(purchase_counts, labels=purchase_counts.index, autopct='%.2f%%', startangle=90)
plt.title('Purchase Distribution')
plt.show()

# %%
dd['Purchased'].value_counts()

# %%
dd['Purchased'].value_counts().index

# %%
plt.pie(dd['Purchased'].value_counts(), labels=dd['Purchased'].value_counts().index, autopct='%.2f%%');
Execution outpu

# %%
plt.boxplot(dd['Age'])

# %%
dd.iloc[2,2] = 9

# %%
q3= np.percentile(df['age'],75)
q1= np.percentile(df['age'],25)
q3, q1

# %%
iqr = q3 - q1
iqr

# %%
ub = q3 + 1.5*iqr
lb = q1 - 1.5*iqr
ub, lb

# %%
dd = dd[ (dd['Age'] > lb) & (dd['Age'] < ub) ]

# %%
dd
